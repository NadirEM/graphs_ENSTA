# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplcyberpunk

results_015 = pd.read_csv('results_015.csv', sep = ' ', header = None)[[0,1]]
errors_015 = pd.read_csv('errors_015.csv', sep = ' ', header = None)[[0,1]]

# %%
results_02 = pd.read_csv('results_01.csv', sep = ' ', header = None)[[0,1]]
results_02 = pd.read_csv('results_02.csv', sep = ' ', header = None)[[0,1]]
results_09 = pd.read_csv('results_09.csv', sep = ' ', header = None)[[0,1]]
results_05 = pd.read_csv('results_05.csv', sep = ' ', header = None)[[0,1]]

# %%
    plt.style.use("cyberpunk")
    fig, ax = plt.subplots(figsize=(10, 10))
    
    
    ax.plot(list(errors_015[1][0:10]), marker='o',linewidth = 2, markersize=3 , color = 'r', label = 'Error')
   
    
    ax.plot([0.001]*10,  linewidth = 2,color = 'g', label = 'Threshold(0.001)')
  #  mplcyberpunk.make_lines_glow(ax)
    ax.set_ylabel('Error', fontsize=25)
    ax.set_xlabel("Nb_iterter", fontsize=25)
    ax.legend(fontsize = 'xx-large')
    plt.xticks(fontsize=24)
    plt.yticks(fontsize=24)


    plt.show()

# %%
plt.style.use("cyberpunk")
fig, ax = plt.subplots(figsize=(5, 5))
mplcyberpunk.add_glow_effects(ax)
ax.scatter(results_015[1],results_02[1] ,marker='o',linewidth = 2, color = 'r', label = '0.15 vs 0.2')
ax.legend()   
plt.show()
fig, ax = plt.subplots(figsize=(5, 5))
mplcyberpunk.add_glow_effects(ax)
ax.scatter(results_015[1],results_09[1] ,marker='o',linewidth = 2, color = 'r', label = '0.15 vs 0.9')
ax.legend()   
plt.show()
fig, ax = plt.subplots(figsize=(5, 5))
mplcyberpunk.add_glow_effects(ax)
ax.scatter(results_015[1],results_05[1] ,marker='o',linewidth = 2, color = 'r', label = '0.15 vs 0.5')
ax.legend()   
plt.show()
